# %%
https://biopython-tutorial.readthedocs.io/en/latest/notebooks/13%20-%20Phylogenetics%20with%20Bio.Phylo.html

# %%
import pandas as pd
import csv
import argparse
import os
from Bio import Phylo

# %%
inputtree = '5605taxa_COImini.fasta.treefilerooted.nwk'
taxa = 'namelist.csv'

with open(taxa, "r", encoding="utf8") as taxafile:
        reader = csv.reader(taxafile)
        taxalist = list(reader)
        flattaxalist = [name for sublist in taxalist for name in sublist]

print(flattaxalist)
# Out:
# ['Bactrocera dorsalis', 'Bactrocera_dorsalis', 'Dacus_pedunculatus', 'Bactrocera_spMalayisa14']

# %%
tree = Phylo.read(inputtree, "newick")
tree.get_terminals(tree.common_ancestor(tree.find_clades({"name": 'Dacus_peduculatus*'})))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /var/folders/zb/s73b85rs24j7t9n3wlzn05vc0000gn/T/ipykernel_32505/1670260616.py in <module>
#       1 tree = Phylo.read(inputtree, "newick")
# ----> 2 tree.get_terminals(tree.common_ancestor(tree.find_clades({"name": 'Dacus_peduculatus*'})))
#
# ~/opt/anaconda3/envs/iqtree/lib/python3.8/site-packages/Bio/Phylo/BaseTree.py in get_terminals(self, order)
#     415     def get_terminals(self, order="preorder"):
#     416         """Get a list of all of this tree's terminal (leaf) nodes."""
# --> 417         return list(self.find_clades(terminal=True, order=order))
#     418
#     419     def trace(self, start, finish):
#
# ~/opt/anaconda3/envs/iqtree/lib/python3.8/site-packages/Bio/Phylo/BaseTree.py in find_clades(self, target, terminal, order, **kwargs)
#     380                 return (elem.is_terminal() == terminal) and match_attrs(elem)
#     381
# --> 382         return self._filter_search(is_matching_elem, order, False)
#     383
#     384     def get_path(self, target=None, **kwargs):
#
# ~/opt/anaconda3/envs/iqtree/lib/python3.8/site-packages/Bio/Phylo/BaseTree.py in _filter_search(self, filter_func, order, follow_attrs)
#     286             order_func = order_opts[order]
#     287         except KeyError:
# --> 288             raise ValueError(
#     289                 "Invalid order '%s'; must be one of: %s" % (order, tuple(order_opts))
#     290             ) from None
#
# ValueError: Invalid order 'Clade'; must be one of: ('preorder', 'postorder', 'level')

# %%
tree = Phylo.read(inputtree, "newick")
#print(len(tree.get_terminals(tree.find_clades({"name": 'Bactrocera_spMalayisa14*'}))))

#mrca = tree.common_ancestor(tree.find_clades({"name": 'Dacus_peduculatus*'}))
#print(mrca)
#Phylo.draw_ascii(mrca)
clade = tree.is_monophyletic(tree.find_clades({"name": 'Dacus_pedunculatus*'}))
get_children(clade)

#Phylo.draw_ascii(tree.is_monophyletic(clade))
#Phylo.draw_ascii((tree.get_parent(tree.find_elements({"name": 'Dacus_pedunculatus*'}))))
    
#tree.find_clades({"name": "Dacus_pedunculatus.*"})

#print(len(tree.get_terminals())) # this works
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /var/folders/zb/s73b85rs24j7t9n3wlzn05vc0000gn/T/ipykernel_32066/3636437373.py in <module>
#       5 #print(mrca)
#       6 #Phylo.draw_ascii(mrca)
# ----> 7 clade = tree.is_monophyletic(tree.find_clades({"name": 'Dacus_pedunculatus*'}))
#       8 get_children(clade)
#       9
#
# ~/opt/anaconda3/envs/iqtree/lib/python3.8/site-packages/Bio/Phylo/BaseTree.py in is_monophyletic(self, terminals, *more_terminals)
#     548         current = self.root
#     549         while True:
# --> 550             if set(current.get_terminals()) == target_set:
#     551                 return current
#     552             # Try a narrower subclade
#
# ~/opt/anaconda3/envs/iqtree/lib/python3.8/site-packages/Bio/Phylo/BaseTree.py in get_terminals(self, order)
#     415     def get_terminals(self, order="preorder"):
#     416         """Get a list of all of this tree's terminal (leaf) nodes."""
# --> 417         return list(self.find_clades(terminal=True, order=order))
#     418
#     419     def trace(self, start, finish):
#
# ~/opt/anaconda3/envs/iqtree/lib/python3.8/site-packages/Bio/Phylo/BaseTree.py in _preorder_traverse(root, get_children)
#      39             yield from dfs(v)
#      40
# ---> 41     yield from dfs(root)
#      42
#      43
#
# ~/opt/anaconda3/envs/iqtree/lib/python3.8/site-packages/Bio/Phylo/BaseTree.py in dfs(elem)
#      37         yield elem
#      38         for v in get_children(elem):
# ---> 39             yield from dfs(v)
#      40
#      41     yield from dfs(root)
#
# ~/opt/anaconda3/envs/iqtree/lib/python3.8/site-packages/Bio/Phylo/BaseTree.py in dfs(elem)
#      37         yield elem
#      38         for v in get_children(elem):
# ---> 39             yield from dfs(v)
#      40
#      41     yield from dfs(root)
#
# ~/opt/anaconda3/envs/iqtree/lib/python3.8/site-packages/Bio/Phylo/BaseTree.py in dfs(elem)
#      37         yield elem
#      38         for v in get_children(elem):
# ---> 39             yield from dfs(v)
#      40
#      41     yield from dfs(root)
#
# ~/opt/anaconda3/envs/iqtree/lib/python3.8/site-packages/Bio/Phylo/BaseTree.py in dfs(elem)
#      37         yield elem
#      38         for v in get_children(elem):
# ---> 39             yield from dfs(v)
#      40
#      41     yield from dfs(root)
#
# ~/opt/anaconda3/envs/iqtree/lib/python3.8/site-packages/Bio/Phylo/BaseTree.py in dfs(elem)
#      37         yield elem
#      38         for v in get_children(elem):
# ---> 39             yield from dfs(v)
#      40
#      41     yield from dfs(root)
#
# ~/opt/anaconda3/envs/iqtree/lib/python3.8/site-packages/Bio/Phylo/BaseTree.py in dfs(elem)
#      37         yield elem
#      38         for v in get_children(elem):
# ---> 39             yield from dfs(v)
#      40
#      41     yield from dfs(root)
#
# ~/opt/anaconda3/envs/iqtree/lib/python3.8/site-packages/Bio/Phylo/BaseTree.py in dfs(elem)
#      37         yield elem
#      38         for v in get_children(elem):
# ---> 39             yield from dfs(v)
#      40
#      41     yield from dfs(root)
#
# ~/opt/anaconda3/envs/iqtree/lib/python3.8/site-packages/Bio/Phylo/BaseTree.py in dfs(elem)
#      37         yield elem
#      38         for v in get_children(elem):
# ---> 39             yield from dfs(v)
#      40
#      41     yield from dfs(root)
#
# ~/opt/anaconda3/envs/iqtree/lib/python3.8/site-packages/Bio/Phylo/BaseTree.py in dfs(elem)
#      37         yield elem
#      38         for v in get_children(elem):
# ---> 39             yield from dfs(v)
#      40
#      41     yield from dfs(root)
#
# ~/opt/anaconda3/envs/iqtree/lib/python3.8/site-packages/Bio/Phylo/BaseTree.py in dfs(elem)
#      37         yield elem
#      38         for v in get_children(elem):
# ---> 39             yield from dfs(v)
#      40
#      41     yield from dfs(root)
#
# ~/opt/anaconda3/envs/iqtree/lib/python3.8/site-packages/Bio/Phylo/BaseTree.py in dfs(elem)
#      37         yield elem
#      38         for v in get_children(elem):
# ---> 39             yield from dfs(v)
#      40
#      41     yield from dfs(root)
#
# ~/opt/anaconda3/envs/iqtree/lib/python3.8/site-packages/Bio/Phylo/BaseTree.py in dfs(elem)
#      37         yield elem
#      38         for v in get_children(elem):
# ---> 39             yield from dfs(v)
#      40
#      41     yield from dfs(root)
#
# ~/opt/anaconda3/envs/iqtree/lib/python3.8/site-packages/Bio/Phylo/BaseTree.py in dfs(elem)
#      37         yield elem
#      38         for v in get_children(elem):
# ---> 39             yield from dfs(v)
#      40
#      41     yield from dfs(root)
#
# ~/opt/anaconda3/envs/iqtree/lib/python3.8/site-packages/Bio/Phylo/BaseTree.py in dfs(elem)
#      37         yield elem
#      38         for v in get_children(elem):
# ---> 39             yield from dfs(v)
#      40
#      41     yield from dfs(root)
#
# ~/opt/anaconda3/envs/iqtree/lib/python3.8/site-packages/Bio/Phylo/BaseTree.py in dfs(elem)
#      37         yield elem
#      38         for v in get_children(elem):
# ---> 39             yield from dfs(v)
#      40
#      41     yield from dfs(root)
#
# ~/opt/anaconda3/envs/iqtree/lib/python3.8/site-packages/Bio/Phylo/BaseTree.py in dfs(elem)
#      37         yield elem
#      38         for v in get_children(elem):
# ---> 39             yield from dfs(v)
#      40
#      41     yield from dfs(root)
#
# ~/opt/anaconda3/envs/iqtree/lib/python3.8/site-packages/Bio/Phylo/BaseTree.py in dfs(elem)
#      37         yield elem
#      38         for v in get_children(elem):
# ---> 39             yield from dfs(v)
#      40
#      41     yield from dfs(root)
#
# ~/opt/anaconda3/envs/iqtree/lib/python3.8/site-packages/Bio/Phylo/BaseTree.py in dfs(elem)
#      37         yield elem
#      38         for v in get_children(elem):
# ---> 39             yield from dfs(v)
#      40
#      41     yield from dfs(root)
#
# ~/opt/anaconda3/envs/iqtree/lib/python3.8/site-packages/Bio/Phylo/BaseTree.py in dfs(elem)
#      37         yield elem
#      38         for v in get_children(elem):
# ---> 39             yield from dfs(v)
#      40
#      41     yield from dfs(root)
#
# ~/opt/anaconda3/envs/iqtree/lib/python3.8/site-packages/Bio/Phylo/BaseTree.py in dfs(elem)
#      37         yield elem
#      38         for v in get_children(elem):
# ---> 39             yield from dfs(v)
#      40
#      41     yield from dfs(root)
#
# ~/opt/anaconda3/envs/iqtree/lib/python3.8/site-packages/Bio/Phylo/BaseTree.py in dfs(elem)
#      37         yield elem
#      38         for v in get_children(elem):
# ---> 39             yield from dfs(v)
#      40
#      41     yield from dfs(root)
#
# ~/opt/anaconda3/envs/iqtree/lib/python3.8/site-packages/Bio/Phylo/BaseTree.py in dfs(elem)
#      37         yield elem
#      38         for v in get_children(elem):
# ---> 39             yield from dfs(v)
#      40
#      41     yield from dfs(root)
#
# ~/opt/anaconda3/envs/iqtree/lib/python3.8/site-packages/Bio/Phylo/BaseTree.py in dfs(elem)
#      37         yield elem
#      38         for v in get_children(elem):
# ---> 39             yield from dfs(v)
#      40
#      41     yield from dfs(root)
#
# ~/opt/anaconda3/envs/iqtree/lib/python3.8/site-packages/Bio/Phylo/BaseTree.py in dfs(elem)
#      37         yield elem
#      38         for v in get_children(elem):
# ---> 39             yield from dfs(v)
#      40
#      41     yield from dfs(root)
#
# ~/opt/anaconda3/envs/iqtree/lib/python3.8/site-packages/Bio/Phylo/BaseTree.py in dfs(elem)
#      37         yield elem
#      38         for v in get_children(elem):
# ---> 39             yield from dfs(v)
#      40
#      41     yield from dfs(root)
#
# ~/opt/anaconda3/envs/iqtree/lib/python3.8/site-packages/Bio/Phylo/BaseTree.py in dfs(elem)
#      37         yield elem
#      38         for v in get_children(elem):
# ---> 39             yield from dfs(v)
#      40
#      41     yield from dfs(root)
#
# ~/opt/anaconda3/envs/iqtree/lib/python3.8/site-packages/Bio/Phylo/BaseTree.py in dfs(elem)
#      37         yield elem
#      38         for v in get_children(elem):
# ---> 39             yield from dfs(v)
#      40
#      41     yield from dfs(root)
#
# ~/opt/anaconda3/envs/iqtree/lib/python3.8/site-packages/Bio/Phylo/BaseTree.py in dfs(elem)
#      37         yield elem
#      38         for v in get_children(elem):
# ---> 39             yield from dfs(v)
#      40
#      41     yield from dfs(root)
#
# ~/opt/anaconda3/envs/iqtree/lib/python3.8/site-packages/Bio/Phylo/BaseTree.py in dfs(elem)
#      37         yield elem
#      38         for v in get_children(elem):
# ---> 39             yield from dfs(v)
#      40
#      41     yield from dfs(root)
#
# ~/opt/anaconda3/envs/iqtree/lib/python3.8/site-packages/Bio/Phylo/BaseTree.py in dfs(elem)
#      37         yield elem
#      38         for v in get_children(elem):
# ---> 39             yield from dfs(v)
#      40
#      41     yield from dfs(root)
#
# ~/opt/anaconda3/envs/iqtree/lib/python3.8/site-packages/Bio/Phylo/BaseTree.py in dfs(elem)
#      37         yield elem
#      38         for v in get_children(elem):
# ---> 39             yield from dfs(v)
#      40
#      41     yield from dfs(root)
#
# ~/opt/anaconda3/envs/iqtree/lib/python3.8/site-packages/Bio/Phylo/BaseTree.py in dfs(elem)
#      37         yield elem
#      38         for v in get_children(elem):
# ---> 39             yield from dfs(v)
#      40
#      41     yield from dfs(root)
#
# ~/opt/anaconda3/envs/iqtree/lib/python3.8/site-packages/Bio/Phylo/BaseTree.py in dfs(elem)
#      37         yield elem
#      38         for v in get_children(elem):
# ---> 39             yield from dfs(v)
#      40
#      41     yield from dfs(root)
#
# ~/opt/anaconda3/envs/iqtree/lib/python3.8/site-packages/Bio/Phylo/BaseTree.py in dfs(elem)
#      37         yield elem
#      38         for v in get_children(elem):
# ---> 39             yield from dfs(v)
#      40
#      41     yield from dfs(root)
#
# ~/opt/anaconda3/envs/iqtree/lib/python3.8/site-packages/Bio/Phylo/BaseTree.py in dfs(elem)
#      37         yield elem
#      38         for v in get_children(elem):
# ---> 39             yield from dfs(v)
#      40
#      41     yield from dfs(root)
#
# ~/opt/anaconda3/envs/iqtree/lib/python3.8/site-packages/Bio/Phylo/BaseTree.py in dfs(elem)
#      37         yield elem
#      38         for v in get_children(elem):
# ---> 39             yield from dfs(v)
#      40
#      41     yield from dfs(root)
#
# ~/opt/anaconda3/envs/iqtree/lib/python3.8/site-packages/Bio/Phylo/BaseTree.py in dfs(elem)
#      37         yield elem
#      38         for v in get_children(elem):
# ---> 39             yield from dfs(v)
#      40
#      41     yield from dfs(root)
#
# ~/opt/anaconda3/envs/iqtree/lib/python3.8/site-packages/Bio/Phylo/BaseTree.py in dfs(elem)
#      37         yield elem
#      38         for v in get_children(elem):
# ---> 39             yield from dfs(v)
#      40
#      41     yield from dfs(root)
#
# ~/opt/anaconda3/envs/iqtree/lib/python3.8/site-packages/Bio/Phylo/BaseTree.py in dfs(elem)
#      37         yield elem
#      38         for v in get_children(elem):
# ---> 39             yield from dfs(v)
#      40
#      41     yield from dfs(root)
#
# ~/opt/anaconda3/envs/iqtree/lib/python3.8/site-packages/Bio/Phylo/BaseTree.py in dfs(elem)
#      37         yield elem
#      38         for v in get_children(elem):
# ---> 39             yield from dfs(v)
#      40
#      41     yield from dfs(root)
#
# ~/opt/anaconda3/envs/iqtree/lib/python3.8/site-packages/Bio/Phylo/BaseTree.py in dfs(elem)
#      37         yield elem
#      38         for v in get_children(elem):
# ---> 39             yield from dfs(v)
#      40
#      41     yield from dfs(root)
#
# ~/opt/anaconda3/envs/iqtree/lib/python3.8/site-packages/Bio/Phylo/BaseTree.py in dfs(elem)
#      37         yield elem
#      38         for v in get_children(elem):
# ---> 39             yield from dfs(v)
#      40
#      41     yield from dfs(root)
#
# ~/opt/anaconda3/envs/iqtree/lib/python3.8/site-packages/Bio/Phylo/BaseTree.py in dfs(elem)
#      37         yield elem
#      38         for v in get_children(elem):
# ---> 39             yield from dfs(v)
#      40
#      41     yield from dfs(root)
#
# ~/opt/anaconda3/envs/iqtree/lib/python3.8/site-packages/Bio/Phylo/BaseTree.py in dfs(elem)
#      37         yield elem
#      38         for v in get_children(elem):
# ---> 39             yield from dfs(v)
#      40
#      41     yield from dfs(root)
#
# ~/opt/anaconda3/envs/iqtree/lib/python3.8/site-packages/Bio/Phylo/BaseTree.py in dfs(elem)
#      37         yield elem
#      38         for v in get_children(elem):
# ---> 39             yield from dfs(v)
#      40
#      41     yield from dfs(root)
#
# ~/opt/anaconda3/envs/iqtree/lib/python3.8/site-packages/Bio/Phylo/BaseTree.py in dfs(elem)
#      37         yield elem
#      38         for v in get_children(elem):
# ---> 39             yield from dfs(v)
#      40
#      41     yield from dfs(root)
#
# ~/opt/anaconda3/envs/iqtree/lib/python3.8/site-packages/Bio/Phylo/BaseTree.py in dfs(elem)
#      37         yield elem
#      38         for v in get_children(elem):
# ---> 39             yield from dfs(v)
#      40
#      41     yield from dfs(root)
#
# ~/opt/anaconda3/envs/iqtree/lib/python3.8/site-packages/Bio/Phylo/BaseTree.py in dfs(elem)
#      37         yield elem
#      38         for v in get_children(elem):
# ---> 39             yield from dfs(v)
#      40
#      41     yield from dfs(root)
#
# ~/opt/anaconda3/envs/iqtree/lib/python3.8/site-packages/Bio/Phylo/BaseTree.py in dfs(elem)
#      37         yield elem
#      38         for v in get_children(elem):
# ---> 39             yield from dfs(v)
#      40
#      41     yield from dfs(root)
#
# ~/opt/anaconda3/envs/iqtree/lib/python3.8/site-packages/Bio/Phylo/BaseTree.py in dfs(elem)
#      37         yield elem
#      38         for v in get_children(elem):
# ---> 39             yield from dfs(v)
#      40
#      41     yield from dfs(root)
#
# ~/opt/anaconda3/envs/iqtree/lib/python3.8/site-packages/Bio/Phylo/BaseTree.py in dfs(elem)
#      37         yield elem
#      38         for v in get_children(elem):
# ---> 39             yield from dfs(v)
#      40
#      41     yield from dfs(root)
#
# ~/opt/anaconda3/envs/iqtree/lib/python3.8/site-packages/Bio/Phylo/BaseTree.py in dfs(elem)
#      37         yield elem
#      38         for v in get_children(elem):
# ---> 39             yield from dfs(v)
#      40
#      41     yield from dfs(root)
#
# ~/opt/anaconda3/envs/iqtree/lib/python3.8/site-packages/Bio/Phylo/BaseTree.py in dfs(elem)
#      37         yield elem
#      38         for v in get_children(elem):
# ---> 39             yield from dfs(v)
#      40
#      41     yield from dfs(root)
#
# ~/opt/anaconda3/envs/iqtree/lib/python3.8/site-packages/Bio/Phylo/BaseTree.py in dfs(elem)
#      37         yield elem
#      38         for v in get_children(elem):
# ---> 39             yield from dfs(v)
#      40
#      41     yield from dfs(root)
#
# ~/opt/anaconda3/envs/iqtree/lib/python3.8/site-packages/Bio/Phylo/BaseTree.py in dfs(elem)
#      37         yield elem
#      38         for v in get_children(elem):
# ---> 39             yield from dfs(v)
#      40
#      41     yield from dfs(root)
#
# ~/opt/anaconda3/envs/iqtree/lib/python3.8/site-packages/Bio/Phylo/BaseTree.py in dfs(elem)
#      37         yield elem
#      38         for v in get_children(elem):
# ---> 39             yield from dfs(v)
#      40
#      41     yield from dfs(root)
#
# ~/opt/anaconda3/envs/iqtree/lib/python3.8/site-packages/Bio/Phylo/BaseTree.py in dfs(elem)
#      37         yield elem
#      38         for v in get_children(elem):
# ---> 39             yield from dfs(v)
#      40
#      41     yield from dfs(root)
#
# ~/opt/anaconda3/envs/iqtree/lib/python3.8/site-packages/Bio/Phylo/BaseTree.py in dfs(elem)
#      37         yield elem
#      38         for v in get_children(elem):
# ---> 39             yield from dfs(v)
#      40
#      41     yield from dfs(root)
#
# ~/opt/anaconda3/envs/iqtree/lib/python3.8/site-packages/Bio/Phylo/BaseTree.py in dfs(elem)
#      37         yield elem
#      38         for v in get_children(elem):
# ---> 39             yield from dfs(v)
#      40
#      41     yield from dfs(root)
#
# ~/opt/anaconda3/envs/iqtree/lib/python3.8/site-packages/Bio/Phylo/BaseTree.py in dfs(elem)
#      37         yield elem
#      38         for v in get_children(elem):
# ---> 39             yield from dfs(v)
#      40
#      41     yield from dfs(root)
#
# ~/opt/anaconda3/envs/iqtree/lib/python3.8/site-packages/Bio/Phylo/BaseTree.py in dfs(elem)
#      37         yield elem
#      38         for v in get_children(elem):
# ---> 39             yield from dfs(v)
#      40
#      41     yield from dfs(root)
#
# ~/opt/anaconda3/envs/iqtree/lib/python3.8/site-packages/Bio/Phylo/BaseTree.py in dfs(elem)
#      37         yield elem
#      38         for v in get_children(elem):
# ---> 39             yield from dfs(v)
#      40
#      41     yield from dfs(root)
#
# ~/opt/anaconda3/envs/iqtree/lib/python3.8/site-packages/Bio/Phylo/BaseTree.py in dfs(elem)
#      37         yield elem
#      38         for v in get_children(elem):
# ---> 39             yield from dfs(v)
#      40
#      41     yield from dfs(root)
#
# ~/opt/anaconda3/envs/iqtree/lib/python3.8/site-packages/Bio/Phylo/BaseTree.py in dfs(elem)
#      37         yield elem
#      38         for v in get_children(elem):
# ---> 39             yield from dfs(v)
#      40
#      41     yield from dfs(root)
#
# ~/opt/anaconda3/envs/iqtree/lib/python3.8/site-packages/Bio/Phylo/BaseTree.py in dfs(elem)
#      37         yield elem
#      38         for v in get_children(elem):
# ---> 39             yield from dfs(v)
#      40
#      41     yield from dfs(root)
#
# ~/opt/anaconda3/envs/iqtree/lib/python3.8/site-packages/Bio/Phylo/BaseTree.py in dfs(elem)
#      37         yield elem
#      38         for v in get_children(elem):
# ---> 39             yield from dfs(v)
#      40
#      41     yield from dfs(root)
#
# ~/opt/anaconda3/envs/iqtree/lib/python3.8/site-packages/Bio/Phylo/BaseTree.py in dfs(elem)
#      37         yield elem
#      38         for v in get_children(elem):
# ---> 39             yield from dfs(v)
#      40
#      41     yield from dfs(root)
#
# ~/opt/anaconda3/envs/iqtree/lib/python3.8/site-packages/Bio/Phylo/BaseTree.py in dfs(elem)
#      37         yield elem
#      38         for v in get_children(elem):
# ---> 39             yield from dfs(v)
#      40
#      41     yield from dfs(root)
#
# ~/opt/anaconda3/envs/iqtree/lib/python3.8/site-packages/Bio/Phylo/BaseTree.py in dfs(elem)
#      37         yield elem
#      38         for v in get_children(elem):
# ---> 39             yield from dfs(v)
#      40
#      41     yield from dfs(root)
#
# ~/opt/anaconda3/envs/iqtree/lib/python3.8/site-packages/Bio/Phylo/BaseTree.py in dfs(elem)
#      37         yield elem
#      38         for v in get_children(elem):
# ---> 39             yield from dfs(v)
#      40
#      41     yield from dfs(root)
#
# ~/opt/anaconda3/envs/iqtree/lib/python3.8/site-packages/Bio/Phylo/BaseTree.py in dfs(elem)
#      37         yield elem
#      38         for v in get_children(elem):
# ---> 39             yield from dfs(v)
#      40
#      41     yield from dfs(root)
#
# ~/opt/anaconda3/envs/iqtree/lib/python3.8/site-packages/Bio/Phylo/BaseTree.py in dfs(elem)
#      37         yield elem
#      38         for v in get_children(elem):
# ---> 39             yield from dfs(v)
#      40
#      41     yield from dfs(root)
#
# ~/opt/anaconda3/envs/iqtree/lib/python3.8/site-packages/Bio/Phylo/BaseTree.py in dfs(elem)
#      37         yield elem
#      38         for v in get_children(elem):
# ---> 39             yield from dfs(v)
#      40
#      41     yield from dfs(root)
#
# ~/opt/anaconda3/envs/iqtree/lib/python3.8/site-packages/Bio/Phylo/BaseTree.py in dfs(elem)
#      37         yield elem
#      38         for v in get_children(elem):
# ---> 39             yield from dfs(v)
#      40
#      41     yield from dfs(root)
#
# ~/opt/anaconda3/envs/iqtree/lib/python3.8/site-packages/Bio/Phylo/BaseTree.py in dfs(elem)
#      37         yield elem
#      38         for v in get_children(elem):
# ---> 39             yield from dfs(v)
#      40
#      41     yield from dfs(root)
#
# ~/opt/anaconda3/envs/iqtree/lib/python3.8/site-packages/Bio/Phylo/BaseTree.py in dfs(elem)
#      37         yield elem
#      38         for v in get_children(elem):
# ---> 39             yield from dfs(v)
#      40
#      41     yield from dfs(root)
#
# ~/opt/anaconda3/envs/iqtree/lib/python3.8/site-packages/Bio/Phylo/BaseTree.py in dfs(elem)
#      37         yield elem
#      38         for v in get_children(elem):
# ---> 39             yield from dfs(v)
#      40
#      41     yield from dfs(root)
#
# ~/opt/anaconda3/envs/iqtree/lib/python3.8/site-packages/Bio/Phylo/BaseTree.py in dfs(elem)
#      37         yield elem
#      38         for v in get_children(elem):
# ---> 39             yield from dfs(v)
#      40
#      41     yield from dfs(root)
#
# ~/opt/anaconda3/envs/iqtree/lib/python3.8/site-packages/Bio/Phylo/BaseTree.py in dfs(elem)
#      37         yield elem
#      38         for v in get_children(elem):
# ---> 39             yield from dfs(v)
#      40
#      41     yield from dfs(root)
#
# ~/opt/anaconda3/envs/iqtree/lib/python3.8/site-packages/Bio/Phylo/BaseTree.py in dfs(elem)
#      37         yield elem
#      38         for v in get_children(elem):
# ---> 39             yield from dfs(v)
#      40
#      41     yield from dfs(root)
#
# ~/opt/anaconda3/envs/iqtree/lib/python3.8/site-packages/Bio/Phylo/BaseTree.py in dfs(elem)
#      37         yield elem
#      38         for v in get_children(elem):
# ---> 39             yield from dfs(v)
#      40
#      41     yield from dfs(root)
#
# ~/opt/anaconda3/envs/iqtree/lib/python3.8/site-packages/Bio/Phylo/BaseTree.py in dfs(elem)
#      37         yield elem
#      38         for v in get_children(elem):
# ---> 39             yield from dfs(v)
#      40
#      41     yield from dfs(root)
#
# ~/opt/anaconda3/envs/iqtree/lib/python3.8/site-packages/Bio/Phylo/BaseTree.py in dfs(elem)
#      37         yield elem
#      38         for v in get_children(elem):
# ---> 39             yield from dfs(v)
#      40
#      41     yield from dfs(root)
#
# ~/opt/anaconda3/envs/iqtree/lib/python3.8/site-packages/Bio/Phylo/BaseTree.py in dfs(elem)
#      37         yield elem
#      38         for v in get_children(elem):
# ---> 39             yield from dfs(v)
#      40
#      41     yield from dfs(root)
#
# ~/opt/anaconda3/envs/iqtree/lib/python3.8/site-packages/Bio/Phylo/BaseTree.py in dfs(elem)
#      37         yield elem
#      38         for v in get_children(elem):
# ---> 39             yield from dfs(v)
#      40
#      41     yield from dfs(root)
#
# ~/opt/anaconda3/envs/iqtree/lib/python3.8/site-packages/Bio/Phylo/BaseTree.py in dfs(elem)
#      37         yield elem
#      38         for v in get_children(elem):
# ---> 39             yield from dfs(v)
#      40
#      41     yield from dfs(root)
#
# ~/opt/anaconda3/envs/iqtree/lib/python3.8/site-packages/Bio/Phylo/BaseTree.py in dfs(elem)
#      37         yield elem
#      38         for v in get_children(elem):
# ---> 39             yield from dfs(v)
#      40
#      41     yield from dfs(root)
#
# ~/opt/anaconda3/envs/iqtree/lib/python3.8/site-packages/Bio/Phylo/BaseTree.py in dfs(elem)
#      37         yield elem
#      38         for v in get_children(elem):
# ---> 39             yield from dfs(v)
#      40
#      41     yield from dfs(root)
#
# ~/opt/anaconda3/envs/iqtree/lib/python3.8/site-packages/Bio/Phylo/BaseTree.py in dfs(elem)
#      37         yield elem
#      38         for v in get_children(elem):
# ---> 39             yield from dfs(v)
#      40
#      41     yield from dfs(root)
#
# ~/opt/anaconda3/envs/iqtree/lib/python3.8/site-packages/Bio/Phylo/BaseTree.py in dfs(elem)
#      37         yield elem
#      38         for v in get_children(elem):
# ---> 39             yield from dfs(v)
#      40
#      41     yield from dfs(root)
#
# ~/opt/anaconda3/envs/iqtree/lib/python3.8/site-packages/Bio/Phylo/BaseTree.py in dfs(elem)
#      37         yield elem
#      38         for v in get_children(elem):
# ---> 39             yield from dfs(v)
#      40
#      41     yield from dfs(root)
#
# ~/opt/anaconda3/envs/iqtree/lib/python3.8/site-packages/Bio/Phylo/BaseTree.py in dfs(elem)
#      37         yield elem
#      38         for v in get_children(elem):
# ---> 39             yield from dfs(v)
#      40
#      41     yield from dfs(root)
#
# ~/opt/anaconda3/envs/iqtree/lib/python3.8/site-packages/Bio/Phylo/BaseTree.py in dfs(elem)
#      37         yield elem
#      38         for v in get_children(elem):
# ---> 39             yield from dfs(v)
#      40
#      41     yield from dfs(root)
#
# ~/opt/anaconda3/envs/iqtree/lib/python3.8/site-packages/Bio/Phylo/BaseTree.py in dfs(elem)
#      37         yield elem
#      38         for v in get_children(elem):
# ---> 39             yield from dfs(v)
#      40
#      41     yield from dfs(root)
#
# ~/opt/anaconda3/envs/iqtree/lib/python3.8/site-packages/Bio/Phylo/BaseTree.py in dfs(elem)
#      37         yield elem
#      38         for v in get_children(elem):
# ---> 39             yield from dfs(v)
#      40
#      41     yield from dfs(root)
#
# ~/opt/anaconda3/envs/iqtree/lib/python3.8/site-packages/Bio/Phylo/BaseTree.py in dfs(elem)
#      37         yield elem
#      38         for v in get_children(elem):
# ---> 39             yield from dfs(v)
#      40
#      41     yield from dfs(root)
#
# ~/opt/anaconda3/envs/iqtree/lib/python3.8/site-packages/Bio/Phylo/BaseTree.py in dfs(elem)
#      37         yield elem
#      38         for v in get_children(elem):
# ---> 39             yield from dfs(v)
#      40
#      41     yield from dfs(root)
#
# ~/opt/anaconda3/envs/iqtree/lib/python3.8/site-packages/Bio/Phylo/BaseTree.py in dfs(elem)
#      37         yield elem
#      38         for v in get_children(elem):
# ---> 39             yield from dfs(v)
#      40
#      41     yield from dfs(root)
#
# ~/opt/anaconda3/envs/iqtree/lib/python3.8/site-packages/Bio/Phylo/BaseTree.py in dfs(elem)
#      37         yield elem
#      38         for v in get_children(elem):
# ---> 39             yield from dfs(v)
#      40
#      41     yield from dfs(root)
#
# ~/opt/anaconda3/envs/iqtree/lib/python3.8/site-packages/Bio/Phylo/BaseTree.py in dfs(elem)
#      37         yield elem
#      38         for v in get_children(elem):
# ---> 39             yield from dfs(v)
#      40
#      41     yield from dfs(root)
#
# ~/opt/anaconda3/envs/iqtree/lib/python3.8/site-packages/Bio/Phylo/BaseTree.py in dfs(elem)
#      37         yield elem
#      38         for v in get_children(elem):
# ---> 39             yield from dfs(v)
#      40
#      41     yield from dfs(root)
#
# ~/opt/anaconda3/envs/iqtree/lib/python3.8/site-packages/Bio/Phylo/BaseTree.py in dfs(elem)
#      37         yield elem
#      38         for v in get_children(elem):
# ---> 39             yield from dfs(v)
#      40
#      41     yield from dfs(root)
#
# ~/opt/anaconda3/envs/iqtree/lib/python3.8/site-packages/Bio/Phylo/BaseTree.py in dfs(elem)
#      37         yield elem
#      38         for v in get_children(elem):
# ---> 39             yield from dfs(v)
#      40
#      41     yield from dfs(root)
#
# ~/opt/anaconda3/envs/iqtree/lib/python3.8/site-packages/Bio/Phylo/BaseTree.py in dfs(elem)
#      37         yield elem
#      38         for v in get_children(elem):
# ---> 39             yield from dfs(v)
#      40
#      41     yield from dfs(root)
#
# ~/opt/anaconda3/envs/iqtree/lib/python3.8/site-packages/Bio/Phylo/BaseTree.py in dfs(elem)
#      37         yield elem
#      38         for v in get_children(elem):
# ---> 39             yield from dfs(v)
#      40
#      41     yield from dfs(root)
#
# ~/opt/anaconda3/envs/iqtree/lib/python3.8/site-packages/Bio/Phylo/BaseTree.py in dfs(elem)
#      37         yield elem
#      38         for v in get_children(elem):
# ---> 39             yield from dfs(v)
#      40
#      41     yield from dfs(root)
#
# ~/opt/anaconda3/envs/iqtree/lib/python3.8/site-packages/Bio/Phylo/BaseTree.py in dfs(elem)
#      37         yield elem
#      38         for v in get_children(elem):
# ---> 39             yield from dfs(v)
#      40
#      41     yield from dfs(root)
#
# ~/opt/anaconda3/envs/iqtree/lib/python3.8/site-packages/Bio/Phylo/BaseTree.py in dfs(elem)
#      37         yield elem
#      38         for v in get_children(elem):
# ---> 39             yield from dfs(v)
#      40
#      41     yield from dfs(root)
#
# ~/opt/anaconda3/envs/iqtree/lib/python3.8/site-packages/Bio/Phylo/BaseTree.py in dfs(elem)
#      37         yield elem
#      38         for v in get_children(elem):
# ---> 39             yield from dfs(v)
#      40
#      41     yield from dfs(root)
#
# ~/opt/anaconda3/envs/iqtree/lib/python3.8/site-packages/Bio/Phylo/BaseTree.py in dfs(elem)
#      37         yield elem
#      38         for v in get_children(elem):
# ---> 39             yield from dfs(v)
#      40
#      41     yield from dfs(root)
#
# ~/opt/anaconda3/envs/iqtree/lib/python3.8/site-packages/Bio/Phylo/BaseTree.py in dfs(elem)
#      37         yield elem
#      38         for v in get_children(elem):
# ---> 39             yield from dfs(v)
#      40
#      41     yield from dfs(root)
#
# ~/opt/anaconda3/envs/iqtree/lib/python3.8/site-packages/Bio/Phylo/BaseTree.py in dfs(elem)
#      37         yield elem
#      38         for v in get_children(elem):
# ---> 39             yield from dfs(v)
#      40
#      41     yield from dfs(root)
#
# ~/opt/anaconda3/envs/iqtree/lib/python3.8/site-packages/Bio/Phylo/BaseTree.py in dfs(elem)
#      37         yield elem
#      38         for v in get_children(elem):
# ---> 39             yield from dfs(v)
#      40
#      41     yield from dfs(root)
#
# ~/opt/anaconda3/envs/iqtree/lib/python3.8/site-packages/Bio/Phylo/BaseTree.py in dfs(elem)
#      37         yield elem
#      38         for v in get_children(elem):
# ---> 39             yield from dfs(v)
#      40
#      41     yield from dfs(root)
#
# ~/opt/anaconda3/envs/iqtree/lib/python3.8/site-packages/Bio/Phylo/BaseTree.py in dfs(elem)
#      37         yield elem
#      38         for v in get_children(elem):
# ---> 39             yield from dfs(v)
#      40
#      41     yield from dfs(root)
#
# ~/opt/anaconda3/envs/iqtree/lib/python3.8/site-packages/Bio/Phylo/BaseTree.py in dfs(elem)
#      37         yield elem
#      38         for v in get_children(elem):
# ---> 39             yield from dfs(v)
#      40
#      41     yield from dfs(root)
#
# ~/opt/anaconda3/envs/iqtree/lib/python3.8/site-packages/Bio/Phylo/BaseTree.py in dfs(elem)
#      37         yield elem
#      38         for v in get_children(elem):
# ---> 39             yield from dfs(v)
#      40
#      41     yield from dfs(root)
#
# ~/opt/anaconda3/envs/iqtree/lib/python3.8/site-packages/Bio/Phylo/BaseTree.py in dfs(elem)
#      37         yield elem
#      38         for v in get_children(elem):
# ---> 39             yield from dfs(v)
#      40
#      41     yield from dfs(root)
#
# ~/opt/anaconda3/envs/iqtree/lib/python3.8/site-packages/Bio/Phylo/BaseTree.py in dfs(elem)
#      37         yield elem
#      38         for v in get_children(elem):
# ---> 39             yield from dfs(v)
#      40
#      41     yield from dfs(root)
#
# ~/opt/anaconda3/envs/iqtree/lib/python3.8/site-packages/Bio/Phylo/BaseTree.py in dfs(elem)
#      37         yield elem
#      38         for v in get_children(elem):
# ---> 39             yield from dfs(v)
#      40
#      41     yield from dfs(root)
#
# ~/opt/anaconda3/envs/iqtree/lib/python3.8/site-packages/Bio/Phylo/BaseTree.py in dfs(elem)
#      37         yield elem
#      38         for v in get_children(elem):
# ---> 39             yield from dfs(v)
#      40
#      41     yield from dfs(root)
#
# ~/opt/anaconda3/envs/iqtree/lib/python3.8/site-packages/Bio/Phylo/BaseTree.py in dfs(elem)
#      37         yield elem
#      38         for v in get_children(elem):
# ---> 39             yield from dfs(v)
#      40
#      41     yield from dfs(root)
#
# ~/opt/anaconda3/envs/iqtree/lib/python3.8/site-packages/Bio/Phylo/BaseTree.py in dfs(elem)
#      37         yield elem
#      38         for v in get_children(elem):
# ---> 39             yield from dfs(v)
#      40
#      41     yield from dfs(root)
#
# ~/opt/anaconda3/envs/iqtree/lib/python3.8/site-packages/Bio/Phylo/BaseTree.py in dfs(elem)
#      37         yield elem
#      38         for v in get_children(elem):
# ---> 39             yield from dfs(v)
#      40
#      41     yield from dfs(root)
#
# ~/opt/anaconda3/envs/iqtree/lib/python3.8/site-packages/Bio/Phylo/BaseTree.py in dfs(elem)
#      37         yield elem
#      38         for v in get_children(elem):
# ---> 39             yield from dfs(v)
#      40
#      41     yield from dfs(root)
#
# ~/opt/anaconda3/envs/iqtree/lib/python3.8/site-packages/Bio/Phylo/BaseTree.py in dfs(elem)
#      37         yield elem
#      38         for v in get_children(elem):
# ---> 39             yield from dfs(v)
#      40
#      41     yield from dfs(root)
#
# ~/opt/anaconda3/envs/iqtree/lib/python3.8/site-packages/Bio/Phylo/BaseTree.py in dfs(elem)
#      37         yield elem
#      38         for v in get_children(elem):
# ---> 39             yield from dfs(v)
#      40
#      41     yield from dfs(root)
#
# ~/opt/anaconda3/envs/iqtree/lib/python3.8/site-packages/Bio/Phylo/BaseTree.py in dfs(elem)
#      37         yield elem
#      38         for v in get_children(elem):
# ---> 39             yield from dfs(v)
#      40
#      41     yield from dfs(root)
#
# ~/opt/anaconda3/envs/iqtree/lib/python3.8/site-packages/Bio/Phylo/BaseTree.py in dfs(elem)
#      37         yield elem
#      38         for v in get_children(elem):
# ---> 39             yield from dfs(v)
#      40
#      41     yield from dfs(root)
#
# ~/opt/anaconda3/envs/iqtree/lib/python3.8/site-packages/Bio/Phylo/BaseTree.py in dfs(elem)
#      37         yield elem
#      38         for v in get_children(elem):
# ---> 39             yield from dfs(v)
#      40
#      41     yield from dfs(root)
#
# ~/opt/anaconda3/envs/iqtree/lib/python3.8/site-packages/Bio/Phylo/BaseTree.py in dfs(elem)
#      37         yield elem
#      38         for v in get_children(elem):
# ---> 39             yield from dfs(v)
#      40
#      41     yield from dfs(root)
#
# ~/opt/anaconda3/envs/iqtree/lib/python3.8/site-packages/Bio/Phylo/BaseTree.py in dfs(elem)
#      37         yield elem
#      38         for v in get_children(elem):
# ---> 39             yield from dfs(v)
#      40
#      41     yield from dfs(root)
#
# ~/opt/anaconda3/envs/iqtree/lib/python3.8/site-packages/Bio/Phylo/BaseTree.py in dfs(elem)
#      37         yield elem
#      38         for v in get_children(elem):
# ---> 39             yield from dfs(v)
#      40
#      41     yield from dfs(root)
#
# ~/opt/anaconda3/envs/iqtree/lib/python3.8/site-packages/Bio/Phylo/BaseTree.py in dfs(elem)
#      37         yield elem
#      38         for v in get_children(elem):
# ---> 39             yield from dfs(v)
#      40
#      41     yield from dfs(root)
#
# ~/opt/anaconda3/envs/iqtree/lib/python3.8/site-packages/Bio/Phylo/BaseTree.py in dfs(elem)
#      37         yield elem
#      38         for v in get_children(elem):
# ---> 39             yield from dfs(v)
#      40
#      41     yield from dfs(root)
#
# ~/opt/anaconda3/envs/iqtree/lib/python3.8/site-packages/Bio/Phylo/BaseTree.py in dfs(elem)
#      37         yield elem
#      38         for v in get_children(elem):
# ---> 39             yield from dfs(v)
#      40
#      41     yield from dfs(root)
#
# ~/opt/anaconda3/envs/iqtree/lib/python3.8/site-packages/Bio/Phylo/BaseTree.py in dfs(elem)
#      37         yield elem
#      38         for v in get_children(elem):
# ---> 39             yield from dfs(v)
#      40
#      41     yield from dfs(root)
#
# ~/opt/anaconda3/envs/iqtree/lib/python3.8/site-packages/Bio/Phylo/BaseTree.py in dfs(elem)
#      37         yield elem
#      38         for v in get_children(elem):
# ---> 39             yield from dfs(v)
#      40
#      41     yield from dfs(root)
#
# ~/opt/anaconda3/envs/iqtree/lib/python3.8/site-packages/Bio/Phylo/BaseTree.py in dfs(elem)
#      37         yield elem
#      38         for v in get_children(elem):
# ---> 39             yield from dfs(v)
#      40
#      41     yield from dfs(root)
#
# ~/opt/anaconda3/envs/iqtree/lib/python3.8/site-packages/Bio/Phylo/BaseTree.py in dfs(elem)
#      37         yield elem
#      38         for v in get_children(elem):
# ---> 39             yield from dfs(v)
#      40
#      41     yield from dfs(root)
#
# ~/opt/anaconda3/envs/iqtree/lib/python3.8/site-packages/Bio/Phylo/BaseTree.py in dfs(elem)
#      37         yield elem
#      38         for v in get_children(elem):
# ---> 39             yield from dfs(v)
#      40
#      41     yield from dfs(root)
#
# ~/opt/anaconda3/envs/iqtree/lib/python3.8/site-packages/Bio/Phylo/BaseTree.py in dfs(elem)
#      37         yield elem
#      38         for v in get_children(elem):
# ---> 39             yield from dfs(v)
#      40
#      41     yield from dfs(root)
#
# ~/opt/anaconda3/envs/iqtree/lib/python3.8/site-packages/Bio/Phylo/BaseTree.py in dfs(elem)
#      37         yield elem
#      38         for v in get_children(elem):
# ---> 39             yield from dfs(v)
#      40
#      41     yield from dfs(root)
#
# ~/opt/anaconda3/envs/iqtree/lib/python3.8/site-packages/Bio/Phylo/BaseTree.py in dfs(elem)
#      37         yield elem
#      38         for v in get_children(elem):
# ---> 39             yield from dfs(v)
#      40
#      41     yield from dfs(root)
#
# ~/opt/anaconda3/envs/iqtree/lib/python3.8/site-packages/Bio/Phylo/BaseTree.py in dfs(elem)
#      37         yield elem
#      38         for v in get_children(elem):
# ---> 39             yield from dfs(v)
#      40
#      41     yield from dfs(root)
#
# ~/opt/anaconda3/envs/iqtree/lib/python3.8/site-packages/Bio/Phylo/BaseTree.py in dfs(elem)
#      37         yield elem
#      38         for v in get_children(elem):
# ---> 39             yield from dfs(v)
#      40
#      41     yield from dfs(root)
#
# ~/opt/anaconda3/envs/iqtree/lib/python3.8/site-packages/Bio/Phylo/BaseTree.py in dfs(elem)
#      37         yield elem
#      38         for v in get_children(elem):
# ---> 39             yield from dfs(v)
#      40
#      41     yield from dfs(root)
#
# ~/opt/anaconda3/envs/iqtree/lib/python3.8/site-packages/Bio/Phylo/BaseTree.py in dfs(elem)
#      37         yield elem
#      38         for v in get_children(elem):
# ---> 39             yield from dfs(v)
#      40
#      41     yield from dfs(root)
#
# ~/opt/anaconda3/envs/iqtree/lib/python3.8/site-packages/Bio/Phylo/BaseTree.py in dfs(elem)
#      37         yield elem
#      38         for v in get_children(elem):
# ---> 39             yield from dfs(v)
#      40
#      41     yield from dfs(root)
#
# ~/opt/anaconda3/envs/iqtree/lib/python3.8/site-packages/Bio/Phylo/BaseTree.py in dfs(elem)
#      37         yield elem
#      38         for v in get_children(elem):
# ---> 39             yield from dfs(v)
#      40
#      41     yield from dfs(root)
#
# ~/opt/anaconda3/envs/iqtree/lib/python3.8/site-packages/Bio/Phylo/BaseTree.py in dfs(elem)
#      37         yield elem
#      38         for v in get_children(elem):
# ---> 39             yield from dfs(v)
#      40
#      41     yield from dfs(root)
#
# ~/opt/anaconda3/envs/iqtree/lib/python3.8/site-packages/Bio/Phylo/BaseTree.py in dfs(elem)
#      37         yield elem
#      38         for v in get_children(elem):
# ---> 39             yield from dfs(v)
#      40
#      41     yield from dfs(root)
#
# ~/opt/anaconda3/envs/iqtree/lib/python3.8/site-packages/Bio/Phylo/BaseTree.py in dfs(elem)
#      37         yield elem
#      38         for v in get_children(elem):
# ---> 39             yield from dfs(v)
#      40
#      41     yield from dfs(root)
#
# ~/opt/anaconda3/envs/iqtree/lib/python3.8/site-packages/Bio/Phylo/BaseTree.py in dfs(elem)
#      37         yield elem
#      38         for v in get_children(elem):
# ---> 39             yield from dfs(v)
#      40
#      41     yield from dfs(root)
#
# ~/opt/anaconda3/envs/iqtree/lib/python3.8/site-packages/Bio/Phylo/BaseTree.py in dfs(elem)
#      37         yield elem
#      38         for v in get_children(elem):
# ---> 39             yield from dfs(v)
#      40
#      41     yield from dfs(root)
#
# ~/opt/anaconda3/envs/iqtree/lib/python3.8/site-packages/Bio/Phylo/BaseTree.py in dfs(elem)
#      37         yield elem
#      38         for v in get_children(elem):
# ---> 39             yield from dfs(v)
#      40
#      41     yield from dfs(root)
#
# ~/opt/anaconda3/envs/iqtree/lib/python3.8/site-packages/Bio/Phylo/BaseTree.py in dfs(elem)
#      37         yield elem
#      38         for v in get_children(elem):
# ---> 39             yield from dfs(v)
#      40
#      41     yield from dfs(root)
#
# ~/opt/anaconda3/envs/iqtree/lib/python3.8/site-packages/Bio/Phylo/BaseTree.py in dfs(elem)
#      37         yield elem
#      38         for v in get_children(elem):
# ---> 39             yield from dfs(v)
#      40
#      41     yield from dfs(root)
#
# ~/opt/anaconda3/envs/iqtree/lib/python3.8/site-packages/Bio/Phylo/BaseTree.py in dfs(elem)
#      37         yield elem
#      38         for v in get_children(elem):
# ---> 39             yield from dfs(v)
#      40
#      41     yield from dfs(root)
#
# ~/opt/anaconda3/envs/iqtree/lib/python3.8/site-packages/Bio/Phylo/BaseTree.py in dfs(elem)
#      37         yield elem
#      38         for v in get_children(elem):
# ---> 39             yield from dfs(v)
#      40
#      41     yield from dfs(root)
#
# ~/opt/anaconda3/envs/iqtree/lib/python3.8/site-packages/Bio/Phylo/BaseTree.py in dfs(elem)
#      37         yield elem
#      38         for v in get_children(elem):
# ---> 39             yield from dfs(v)
#      40
#      41     yield from dfs(root)
#
# ~/opt/anaconda3/envs/iqtree/lib/python3.8/site-packages/Bio/Phylo/BaseTree.py in dfs(elem)
#      37         yield elem
#      38         for v in get_children(elem):
# ---> 39             yield from dfs(v)
#      40
#      41     yield from dfs(root)
#
# ~/opt/anaconda3/envs/iqtree/lib/python3.8/site-packages/Bio/Phylo/BaseTree.py in dfs(elem)
#      37         yield elem
#      38         for v in get_children(elem):
# ---> 39             yield from dfs(v)
#      40
#      41     yield from dfs(root)
#
# ~/opt/anaconda3/envs/iqtree/lib/python3.8/site-packages/Bio/Phylo/BaseTree.py in dfs(elem)
#      37         yield elem
#      38         for v in get_children(elem):
# ---> 39             yield from dfs(v)
#      40
#      41     yield from dfs(root)
#
# ~/opt/anaconda3/envs/iqtree/lib/python3.8/site-packages/Bio/Phylo/BaseTree.py in dfs(elem)
#      37         yield elem
#      38         for v in get_children(elem):
# ---> 39             yield from dfs(v)
#      40
#      41     yield from dfs(root)
#
# ~/opt/anaconda3/envs/iqtree/lib/python3.8/site-packages/Bio/Phylo/BaseTree.py in dfs(elem)
#      37         yield elem
#      38         for v in get_children(elem):
# ---> 39             yield from dfs(v)
#      40
#      41     yield from dfs(root)
#
# ~/opt/anaconda3/envs/iqtree/lib/python3.8/site-packages/Bio/Phylo/BaseTree.py in dfs(elem)
#      37         yield elem
#      38         for v in get_children(elem):
# ---> 39             yield from dfs(v)
#      40
#      41     yield from dfs(root)
#
# ~/opt/anaconda3/envs/iqtree/lib/python3.8/site-packages/Bio/Phylo/BaseTree.py in dfs(elem)
#      37         yield elem
#      38         for v in get_children(elem):
# ---> 39             yield from dfs(v)
#      40
#      41     yield from dfs(root)
#
# ~/opt/anaconda3/envs/iqtree/lib/python3.8/site-packages/Bio/Phylo/BaseTree.py in dfs(elem)
#      37         yield elem
#      38         for v in get_children(elem):
# ---> 39             yield from dfs(v)
#      40
#      41     yield from dfs(root)
#
# ~/opt/anaconda3/envs/iqtree/lib/python3.8/site-packages/Bio/Phylo/BaseTree.py in dfs(elem)
#      37         yield elem
#      38         for v in get_children(elem):
# ---> 39             yield from dfs(v)
#      40
#      41     yield from dfs(root)
#
# ~/opt/anaconda3/envs/iqtree/lib/python3.8/site-packages/Bio/Phylo/BaseTree.py in dfs(elem)
#      37         yield elem
#      38         for v in get_children(elem):
# ---> 39             yield from dfs(v)
#      40
#      41     yield from dfs(root)
#
# ~/opt/anaconda3/envs/iqtree/lib/python3.8/site-packages/Bio/Phylo/BaseTree.py in dfs(elem)
#      37         yield elem
#      38         for v in get_children(elem):
# ---> 39             yield from dfs(v)
#      40
#      41     yield from dfs(root)
#
# ~/opt/anaconda3/envs/iqtree/lib/python3.8/site-packages/Bio/Phylo/BaseTree.py in dfs(elem)
#      37         yield elem
#      38         for v in get_children(elem):
# ---> 39             yield from dfs(v)
#      40
#      41     yield from dfs(root)
#
# ~/opt/anaconda3/envs/iqtree/lib/python3.8/site-packages/Bio/Phylo/BaseTree.py in dfs(elem)
#      37         yield elem
#      38         for v in get_children(elem):
# ---> 39             yield from dfs(v)
#      40
#      41     yield from dfs(root)
#
# ~/opt/anaconda3/envs/iqtree/lib/python3.8/site-packages/Bio/Phylo/BaseTree.py in dfs(elem)
#      37         yield elem
#      38         for v in get_children(elem):
# ---> 39             yield from dfs(v)
#      40
#      41     yield from dfs(root)
#
# ~/opt/anaconda3/envs/iqtree/lib/python3.8/site-packages/Bio/Phylo/BaseTree.py in dfs(elem)
#      37         yield elem
#      38         for v in get_children(elem):
# ---> 39             yield from dfs(v)
#      40
#      41     yield from dfs(root)
#
# ~/opt/anaconda3/envs/iqtree/lib/python3.8/site-packages/Bio/Phylo/BaseTree.py in dfs(elem)
#      37         yield elem
#      38         for v in get_children(elem):
# ---> 39             yield from dfs(v)
#      40
#      41     yield from dfs(root)
#
# ~/opt/anaconda3/envs/iqtree/lib/python3.8/site-packages/Bio/Phylo/BaseTree.py in dfs(elem)
#      37         yield elem
#      38         for v in get_children(elem):
# ---> 39             yield from dfs(v)
#      40
#      41     yield from dfs(root)
#
# ~/opt/anaconda3/envs/iqtree/lib/python3.8/site-packages/Bio/Phylo/BaseTree.py in dfs(elem)
#      37         yield elem
#      38         for v in get_children(elem):
# ---> 39             yield from dfs(v)
#      40
#      41     yield from dfs(root)
#
# ~/opt/anaconda3/envs/iqtree/lib/python3.8/site-packages/Bio/Phylo/BaseTree.py in dfs(elem)
#      37         yield elem
#      38         for v in get_children(elem):
# ---> 39             yield from dfs(v)
#      40
#      41     yield from dfs(root)
#
# ~/opt/anaconda3/envs/iqtree/lib/python3.8/site-packages/Bio/Phylo/BaseTree.py in dfs(elem)
#      37         yield elem
#      38         for v in get_children(elem):
# ---> 39             yield from dfs(v)
#      40
#      41     yield from dfs(root)
#
# ~/opt/anaconda3/envs/iqtree/lib/python3.8/site-packages/Bio/Phylo/BaseTree.py in dfs(elem)
#      37         yield elem
#      38         for v in get_children(elem):
# ---> 39             yield from dfs(v)
#      40
#      41     yield from dfs(root)
#
# ~/opt/anaconda3/envs/iqtree/lib/python3.8/site-packages/Bio/Phylo/BaseTree.py in dfs(elem)
#      37         yield elem
#      38         for v in get_children(elem):
# ---> 39             yield from dfs(v)
#      40
#      41     yield from dfs(root)
#
# ~/opt/anaconda3/envs/iqtree/lib/python3.8/site-packages/Bio/Phylo/BaseTree.py in dfs(elem)
#      37         yield elem
#      38         for v in get_children(elem):
# ---> 39             yield from dfs(v)
#      40
#      41     yield from dfs(root)
#
# ~/opt/anaconda3/envs/iqtree/lib/python3.8/site-packages/Bio/Phylo/BaseTree.py in dfs(elem)
#      37         yield elem
#      38         for v in get_children(elem):
# ---> 39             yield from dfs(v)
#      40
#      41     yield from dfs(root)
#
# ~/opt/anaconda3/envs/iqtree/lib/python3.8/site-packages/Bio/Phylo/BaseTree.py in dfs(elem)
#      37         yield elem
#      38         for v in get_children(elem):
# ---> 39             yield from dfs(v)
#      40
#      41     yield from dfs(root)
#
# ~/opt/anaconda3/envs/iqtree/lib/python3.8/site-packages/Bio/Phylo/BaseTree.py in dfs(elem)
#      37         yield elem
#      38         for v in get_children(elem):
# ---> 39             yield from dfs(v)
#      40
#      41     yield from dfs(root)
#
# ~/opt/anaconda3/envs/iqtree/lib/python3.8/site-packages/Bio/Phylo/BaseTree.py in dfs(elem)
#      37         yield elem
#      38         for v in get_children(elem):
# ---> 39             yield from dfs(v)
#      40
#      41     yield from dfs(root)
#
# ~/opt/anaconda3/envs/iqtree/lib/python3.8/site-packages/Bio/Phylo/BaseTree.py in dfs(elem)
#      37         yield elem
#      38         for v in get_children(elem):
# ---> 39             yield from dfs(v)
#      40
#      41     yield from dfs(root)
#
# ~/opt/anaconda3/envs/iqtree/lib/python3.8/site-packages/Bio/Phylo/BaseTree.py in dfs(elem)
#      37         yield elem
#      38         for v in get_children(elem):
# ---> 39             yield from dfs(v)
#      40
#      41     yield from dfs(root)
#
# ~/opt/anaconda3/envs/iqtree/lib/python3.8/site-packages/Bio/Phylo/BaseTree.py in dfs(elem)
#      37         yield elem
#      38         for v in get_children(elem):
# ---> 39             yield from dfs(v)
#      40
#      41     yield from dfs(root)
#
# ...
#      38         for v in get_children(elem):
# ---> 39             yield from dfs(v)
#      40
#      41     yield from dfs(root)
#
# ~/opt/anaconda3/envs/iqtree/lib/python3.8/site-packages/Bio/Phylo/BaseTree.py in dfs(elem)
#      37         yield elem
#      38         for v in get_children(elem):
# ---> 39             yield from dfs(v)
#      40
#      41     yield from dfs(root)
#
# ~/opt/anaconda3/envs/iqtree/lib/python3.8/site-packages/Bio/Phylo/BaseTree.py in dfs(elem)
#      37         yield elem
#      38         for v in get_children(elem):
# ---> 39             yield from dfs(v)
#      40
#      41     yield from dfs(root)
#
# ~/opt/anaconda3/envs/iqtree/lib/python3.8/site-packages/Bio/Phylo/BaseTree.py in dfs(elem)
#      37         yield elem
#      38         for v in get_children(elem):
# ---> 39             yield from dfs(v)
#      40
#      41     yield from dfs(root)
#
# ~/opt/anaconda3/envs/iqtree/lib/python3.8/site-packages/Bio/Phylo/BaseTree.py in dfs(elem)
#      37         yield elem
#      38         for v in get_children(elem):
# ---> 39             yield from dfs(v)
#      40
#      41     yield from dfs(root)
#
# ~/opt/anaconda3/envs/iqtree/lib/python3.8/site-packages/Bio/Phylo/BaseTree.py in dfs(elem)
#      37         yield elem
#      38         for v in get_children(elem):
# ---> 39             yield from dfs(v)
#      40
#      41     yield from dfs(root)
#
# ~/opt/anaconda3/envs/iqtree/lib/python3.8/site-packages/Bio/Phylo/BaseTree.py in dfs(elem)
#      37         yield elem
#      38         for v in get_children(elem):
# ---> 39             yield from dfs(v)
#      40
#      41     yield from dfs(root)
#
# ~/opt/anaconda3/envs/iqtree/lib/python3.8/site-packages/Bio/Phylo/BaseTree.py in dfs(elem)
#      37         yield elem
#      38         for v in get_children(elem):
# ---> 39             yield from dfs(v)
#      40
#      41     yield from dfs(root)
#
# ~/opt/anaconda3/envs/iqtree/lib/python3.8/site-packages/Bio/Phylo/BaseTree.py in dfs(elem)
#      37         yield elem
#      38         for v in get_children(elem):
# ---> 39             yield from dfs(v)
#      40
#      41     yield from dfs(root)
#
# ~/opt/anaconda3/envs/iqtree/lib/python3.8/site-packages/Bio/Phylo/BaseTree.py in dfs(elem)
#      37         yield elem
#      38         for v in get_children(elem):
# ---> 39             yield from dfs(v)
#      40
#      41     yield from dfs(root)
#
# ~/opt/anaconda3/envs/iqtree/lib/python3.8/site-packages/Bio/Phylo/BaseTree.py in dfs(elem)
#      37         yield elem
#      38         for v in get_children(elem):
# ---> 39             yield from dfs(v)
#      40
#      41     yield from dfs(root)
#
# ~/opt/anaconda3/envs/iqtree/lib/python3.8/site-packages/Bio/Phylo/BaseTree.py in dfs(elem)
#      37         yield elem
#      38         for v in get_children(elem):
# ---> 39             yield from dfs(v)
#      40
#      41     yield from dfs(root)
#
# ~/opt/anaconda3/envs/iqtree/lib/python3.8/site-packages/Bio/Phylo/BaseTree.py in dfs(elem)
#      37         yield elem
#      38         for v in get_children(elem):
# ---> 39             yield from dfs(v)
#      40
#      41     yield from dfs(root)
#
# ~/opt/anaconda3/envs/iqtree/lib/python3.8/site-packages/Bio/Phylo/BaseTree.py in dfs(elem)
#      37         yield elem
#      38         for v in get_children(elem):
# ---> 39             yield from dfs(v)
#      40
#      41     yield from dfs(root)
#
# ~/opt/anaconda3/envs/iqtree/lib/python3.8/site-packages/Bio/Phylo/BaseTree.py in dfs(elem)
#      37         yield elem
#      38         for v in get_children(elem):
# ---> 39             yield from dfs(v)
#      40
#      41     yield from dfs(root)
#
# ~/opt/anaconda3/envs/iqtree/lib/python3.8/site-packages/Bio/Phylo/BaseTree.py in dfs(elem)
#      37         yield elem
#      38         for v in get_children(elem):
# ---> 39             yield from dfs(v)
#      40
#      41     yield from dfs(root)
#
# ~/opt/anaconda3/envs/iqtree/lib/python3.8/site-packages/Bio/Phylo/BaseTree.py in dfs(elem)
#      37         yield elem
#      38         for v in get_children(elem):
# ---> 39             yield from dfs(v)
#      40
#      41     yield from dfs(root)
#
# ~/opt/anaconda3/envs/iqtree/lib/python3.8/site-packages/Bio/Phylo/BaseTree.py in dfs(elem)
#      37         yield elem
#      38         for v in get_children(elem):
# ---> 39             yield from dfs(v)
#      40
#      41     yield from dfs(root)
#
# ~/opt/anaconda3/envs/iqtree/lib/python3.8/site-packages/Bio/Phylo/BaseTree.py in dfs(elem)
#      37         yield elem
#      38         for v in get_children(elem):
# ---> 39             yield from dfs(v)
#      40
#      41     yield from dfs(root)
#
# ~/opt/anaconda3/envs/iqtree/lib/python3.8/site-packages/Bio/Phylo/BaseTree.py in dfs(elem)
#      37         yield elem
#      38         for v in get_children(elem):
# ---> 39             yield from dfs(v)
#      40
#      41     yield from dfs(root)
#
# ~/opt/anaconda3/envs/iqtree/lib/python3.8/site-packages/Bio/Phylo/BaseTree.py in dfs(elem)
#      37         yield elem
#      38         for v in get_children(elem):
# ---> 39             yield from dfs(v)
#      40
#      41     yield from dfs(root)
#
# ~/opt/anaconda3/envs/iqtree/lib/python3.8/site-packages/Bio/Phylo/BaseTree.py in dfs(elem)
#      37         yield elem
#      38         for v in get_children(elem):
# ---> 39             yield from dfs(v)
#      40
#      41     yield from dfs(root)
#
# ~/opt/anaconda3/envs/iqtree/lib/python3.8/site-packages/Bio/Phylo/BaseTree.py in dfs(elem)
#      37         yield elem
#      38         for v in get_children(elem):
# ---> 39             yield from dfs(v)
#      40
#      41     yield from dfs(root)
#
# ~/opt/anaconda3/envs/iqtree/lib/python3.8/site-packages/Bio/Phylo/BaseTree.py in dfs(elem)
#      37         yield elem
#      38         for v in get_children(elem):
# ---> 39             yield from dfs(v)
#      40
#      41     yield from dfs(root)
#
# ~/opt/anaconda3/envs/iqtree/lib/python3.8/site-packages/Bio/Phylo/BaseTree.py in dfs(elem)
#      37         yield elem
#      38         for v in get_children(elem):
# ---> 39             yield from dfs(v)
#      40
#      41     yield from dfs(root)
#
# ~/opt/anaconda3/envs/iqtree/lib/python3.8/site-packages/Bio/Phylo/BaseTree.py in dfs(elem)
#      37         yield elem
#      38         for v in get_children(elem):
# ---> 39             yield from dfs(v)
#      40
#      41     yield from dfs(root)
#
# ~/opt/anaconda3/envs/iqtree/lib/python3.8/site-packages/Bio/Phylo/BaseTree.py in dfs(elem)
#      37         yield elem
#      38         for v in get_children(elem):
# ---> 39             yield from dfs(v)
#      40
#      41     yield from dfs(root)
#
# ~/opt/anaconda3/envs/iqtree/lib/python3.8/site-packages/Bio/Phylo/BaseTree.py in dfs(elem)
#      37         yield elem
#      38         for v in get_children(elem):
# ---> 39             yield from dfs(v)
#      40
#      41     yield from dfs(root)
#
# ~/opt/anaconda3/envs/iqtree/lib/python3.8/site-packages/Bio/Phylo/BaseTree.py in dfs(elem)
#      37         yield elem
#      38         for v in get_children(elem):
# ---> 39             yield from dfs(v)
#      40
#      41     yield from dfs(root)
#
# ~/opt/anaconda3/envs/iqtree/lib/python3.8/site-packages/Bio/Phylo/BaseTree.py in dfs(elem)
#      37         yield elem
#      38         for v in get_children(elem):
# ---> 39             yield from dfs(v)
#      40
#      41     yield from dfs(root)
#
# ~/opt/anaconda3/envs/iqtree/lib/python3.8/site-packages/Bio/Phylo/BaseTree.py in dfs(elem)
#      37         yield elem
#      38         for v in get_children(elem):
# ---> 39             yield from dfs(v)
#      40
#      41     yield from dfs(root)
#
# ~/opt/anaconda3/envs/iqtree/lib/python3.8/site-packages/Bio/Phylo/BaseTree.py in dfs(elem)
#      37         yield elem
#      38         for v in get_children(elem):
# ---> 39             yield from dfs(v)
#      40
#      41     yield from dfs(root)
#
# ~/opt/anaconda3/envs/iqtree/lib/python3.8/site-packages/Bio/Phylo/BaseTree.py in dfs(elem)
#      37         yield elem
#      38         for v in get_children(elem):
# ---> 39             yield from dfs(v)
#      40
#      41     yield from dfs(root)
#
# ~/opt/anaconda3/envs/iqtree/lib/python3.8/site-packages/Bio/Phylo/BaseTree.py in dfs(elem)
#      37         yield elem
#      38         for v in get_children(elem):
# ---> 39             yield from dfs(v)
#      40
#      41     yield from dfs(root)
#
# ~/opt/anaconda3/envs/iqtree/lib/python3.8/site-packages/Bio/Phylo/BaseTree.py in dfs(elem)
#      37         yield elem
#      38         for v in get_children(elem):
# ---> 39             yield from dfs(v)
#      40
#      41     yield from dfs(root)
#
# ~/opt/anaconda3/envs/iqtree/lib/python3.8/site-packages/Bio/Phylo/BaseTree.py in dfs(elem)
#      37         yield elem
#      38         for v in get_children(elem):
# ---> 39             yield from dfs(v)
#      40
#      41     yield from dfs(root)
#
# ~/opt/anaconda3/envs/iqtree/lib/python3.8/site-packages/Bio/Phylo/BaseTree.py in dfs(elem)
#      37         yield elem
#      38         for v in get_children(elem):
# ---> 39             yield from dfs(v)
#      40
#      41     yield from dfs(root)
#
# ~/opt/anaconda3/envs/iqtree/lib/python3.8/site-packages/Bio/Phylo/BaseTree.py in dfs(elem)
#      37         yield elem
#      38         for v in get_children(elem):
# ---> 39             yield from dfs(v)
#      40
#      41     yield from dfs(root)
#
# ~/opt/anaconda3/envs/iqtree/lib/python3.8/site-packages/Bio/Phylo/BaseTree.py in dfs(elem)
#      37         yield elem
#      38         for v in get_children(elem):
# ---> 39             yield from dfs(v)
#      40
#      41     yield from dfs(root)
#
# ~/opt/anaconda3/envs/iqtree/lib/python3.8/site-packages/Bio/Phylo/BaseTree.py in dfs(elem)
#      37         yield elem
#      38         for v in get_children(elem):
# ---> 39             yield from dfs(v)
#      40
#      41     yield from dfs(root)
#
# ~/opt/anaconda3/envs/iqtree/lib/python3.8/site-packages/Bio/Phylo/BaseTree.py in dfs(elem)
#      37         yield elem
#      38         for v in get_children(elem):
# ---> 39             yield from dfs(v)
#      40
#      41     yield from dfs(root)
#
# ~/opt/anaconda3/envs/iqtree/lib/python3.8/site-packages/Bio/Phylo/BaseTree.py in dfs(elem)
#      37         yield elem
#      38         for v in get_children(elem):
# ---> 39             yield from dfs(v)
#      40
#      41     yield from dfs(root)
#
# ~/opt/anaconda3/envs/iqtree/lib/python3.8/site-packages/Bio/Phylo/BaseTree.py in dfs(elem)
#      37         yield elem
#      38         for v in get_children(elem):
# ---> 39             yield from dfs(v)
#      40
#      41     yield from dfs(root)
#
# ~/opt/anaconda3/envs/iqtree/lib/python3.8/site-packages/Bio/Phylo/BaseTree.py in dfs(elem)
#      37         yield elem
#      38         for v in get_children(elem):
# ---> 39             yield from dfs(v)
#      40
#      41     yield from dfs(root)
#
# ~/opt/anaconda3/envs/iqtree/lib/python3.8/site-packages/Bio/Phylo/BaseTree.py in dfs(elem)
#      37         yield elem
#      38         for v in get_children(elem):
# ---> 39             yield from dfs(v)
#      40
#      41     yield from dfs(root)
#
# ~/opt/anaconda3/envs/iqtree/lib/python3.8/site-packages/Bio/Phylo/BaseTree.py in dfs(elem)
#      37         yield elem
#      38         for v in get_children(elem):
# ---> 39             yield from dfs(v)
#      40
#      41     yield from dfs(root)
#
# ~/opt/anaconda3/envs/iqtree/lib/python3.8/site-packages/Bio/Phylo/BaseTree.py in dfs(elem)
#      37         yield elem
#      38         for v in get_children(elem):
# ---> 39             yield from dfs(v)
#      40
#      41     yield from dfs(root)
#
# ~/opt/anaconda3/envs/iqtree/lib/python3.8/site-packages/Bio/Phylo/BaseTree.py in dfs(elem)
#      37         yield elem
#      38         for v in get_children(elem):
# ---> 39             yield from dfs(v)
#      40
#      41     yield from dfs(root)
#
# ~/opt/anaconda3/envs/iqtree/lib/python3.8/site-packages/Bio/Phylo/BaseTree.py in dfs(elem)
#      37         yield elem
#      38         for v in get_children(elem):
# ---> 39             yield from dfs(v)
#      40
#      41     yield from dfs(root)
#
# ~/opt/anaconda3/envs/iqtree/lib/python3.8/site-packages/Bio/Phylo/BaseTree.py in dfs(elem)
#      37         yield elem
#      38         for v in get_children(elem):
# ---> 39             yield from dfs(v)
#      40
#      41     yield from dfs(root)
#
# ~/opt/anaconda3/envs/iqtree/lib/python3.8/site-packages/Bio/Phylo/BaseTree.py in dfs(elem)
#      37         yield elem
#      38         for v in get_children(elem):
# ---> 39             yield from dfs(v)
#      40
#      41     yield from dfs(root)
#
# ~/opt/anaconda3/envs/iqtree/lib/python3.8/site-packages/Bio/Phylo/BaseTree.py in dfs(elem)
#      37         yield elem
#      38         for v in get_children(elem):
# ---> 39             yield from dfs(v)
#      40
#      41     yield from dfs(root)
#
# ~/opt/anaconda3/envs/iqtree/lib/python3.8/site-packages/Bio/Phylo/BaseTree.py in dfs(elem)
#      37         yield elem
#      38         for v in get_children(elem):
# ---> 39             yield from dfs(v)
#      40
#      41     yield from dfs(root)
#
# ~/opt/anaconda3/envs/iqtree/lib/python3.8/site-packages/Bio/Phylo/BaseTree.py in dfs(elem)
#      37         yield elem
#      38         for v in get_children(elem):
# ---> 39             yield from dfs(v)
#      40
#      41     yield from dfs(root)
#
# ~/opt/anaconda3/envs/iqtree/lib/python3.8/site-packages/Bio/Phylo/BaseTree.py in dfs(elem)
#      37         yield elem
#      38         for v in get_children(elem):
# ---> 39             yield from dfs(v)
#      40
#      41     yield from dfs(root)
#
# ~/opt/anaconda3/envs/iqtree/lib/python3.8/site-packages/Bio/Phylo/BaseTree.py in dfs(elem)
#      37         yield elem
#      38         for v in get_children(elem):
# ---> 39             yield from dfs(v)
#      40
#      41     yield from dfs(root)
#
# ~/opt/anaconda3/envs/iqtree/lib/python3.8/site-packages/Bio/Phylo/BaseTree.py in dfs(elem)
#      37         yield elem
#      38         for v in get_children(elem):
# ---> 39             yield from dfs(v)
#      40
#      41     yield from dfs(root)
#
# ~/opt/anaconda3/envs/iqtree/lib/python3.8/site-packages/Bio/Phylo/BaseTree.py in dfs(elem)
#      37         yield elem
#      38         for v in get_children(elem):
# ---> 39             yield from dfs(v)
#      40
#      41     yield from dfs(root)
#
# ~/opt/anaconda3/envs/iqtree/lib/python3.8/site-packages/Bio/Phylo/BaseTree.py in dfs(elem)
#      37         yield elem
#      38         for v in get_children(elem):
# ---> 39             yield from dfs(v)
#      40
#      41     yield from dfs(root)
#
# ~/opt/anaconda3/envs/iqtree/lib/python3.8/site-packages/Bio/Phylo/BaseTree.py in dfs(elem)
#      37         yield elem
#      38         for v in get_children(elem):
# ---> 39             yield from dfs(v)
#      40
#      41     yield from dfs(root)
#
# ~/opt/anaconda3/envs/iqtree/lib/python3.8/site-packages/Bio/Phylo/BaseTree.py in dfs(elem)
#      37         yield elem
#      38         for v in get_children(elem):
# ---> 39             yield from dfs(v)
#      40
#      41     yield from dfs(root)
#
# ~/opt/anaconda3/envs/iqtree/lib/python3.8/site-packages/Bio/Phylo/BaseTree.py in dfs(elem)
#      37         yield elem
#      38         for v in get_children(elem):
# ---> 39             yield from dfs(v)
#      40
#      41     yield from dfs(root)
#
# ~/opt/anaconda3/envs/iqtree/lib/python3.8/site-packages/Bio/Phylo/BaseTree.py in dfs(elem)
#      37         yield elem
#      38         for v in get_children(elem):
# ---> 39             yield from dfs(v)
#      40
#      41     yield from dfs(root)
#
# ~/opt/anaconda3/envs/iqtree/lib/python3.8/site-packages/Bio/Phylo/BaseTree.py in dfs(elem)
#      37         yield elem
#      38         for v in get_children(elem):
# ---> 39             yield from dfs(v)
#      40
#      41     yield from dfs(root)
#
# ~/opt/anaconda3/envs/iqtree/lib/python3.8/site-packages/Bio/Phylo/BaseTree.py in dfs(elem)
#      37         yield elem
#      38         for v in get_children(elem):
# ---> 39             yield from dfs(v)
#      40
#      41     yield from dfs(root)
#
# ~/opt/anaconda3/envs/iqtree/lib/python3.8/site-packages/Bio/Phylo/BaseTree.py in dfs(elem)
#      35
#      36     def dfs(elem):
# ---> 37         yield elem
#      38         for v in get_children(elem):
#      39             yield from dfs(v)
#
# KeyboardInterrupt:

# %%
def checkifintree(inputtree, flattaxalist):
    tree = Phylo.read(inputtree, "newick")
    for taxon in flattaxalist:
        try:
            taxonstring = taxon + ".*" #regex matches species name and anything that follows
            tree.root_with_outgroup({"name": taxonstring}) # just to test if taxon is in the tree, will throw exception if not
        except Exception:
            print(taxon + " is not in this tree, skipping")
            flattaxalist.remove(taxon)
    return flattaxalist

# %%
def checkmonophyly(inputtree, flattaxalist):
    tree = Phylo.read(inputtree, "newick")
    tree.rooted = True
    speciesstatus = []
    for taxon in flattaxalist:
        taxonstring = taxon + ".*" #regex matches species name and anything that follows
        if tree.is_monophyletic(tree.find_clades({"name": taxonstring})) is not False:
            print(str(taxon) + " is monophyletic")
            speciesstatus.append({'taxon': taxon, 'monophyly': "monophyletic"})
        else:
            print(str(taxon) + " is non-monophyletic")
            speciesstatus.append({'taxon': taxon, 'monophyly': "non-monophyletic"})
    return speciesstatus

# %%
checkifintree(inputtree, flattaxalist)
speciesstatus = checkmonophyly(inputtree, flattaxalist)
# Out:
# Bactrocera_nigrotibialis is non-monophyletic
# Bactrocera_fagraea is monophyletic
# Bactrocera_kohkongiae is monophyletic
# Bactrocera_usitata is monophyletic
# Zeugodacus_juxtuncinatus is monophyletic
# Zeugodacus_atrifacies is monophyletic
# Zeugodacus_tau is non-monophyletic
# Bactrocera_malaysiensis is monophyletic
# Bactrocera_passiflorae is monophyletic
# Bactrocera_cognata is monophyletic
# Bactrocera_fuscitibia is monophyletic
# Bactrocera_bipustulata is non-monophyletic
# Bactrocera_picea is monophyletic
# Bactrocera_quasiinfulata is non-monophyletic
# Bactrocera_mayi is non-monophyletic
# Bactrocera_bimaculata is monophyletic
# Bactrocera_buinensis is monophyletic
# Zeugodacus_exornatus is monophyletic
# Bactrocera_speculifer is monophyletic
# Bactrocera_pepisalae is monophyletic
# Bactrocera_spMalaysia07 is monophyletic
# Bactrocera_kalimantaniae is non-monophyletic
# Bactrocera_thailandica is monophyletic
# Bactrocera_psidii is non-monophyletic
# Dacus_tenebrosus is monophyletic
# Zeugodacus_cilifer is non-monophyletic
# Bactrocera_wuzhishana is monophyletic
# Bactrocera_tuberculata is monophyletic
# Bactrocera_kanchanaburi is non-monophyletic
# Bactrocera_umbrosa is monophyletic
# Bactrocera_ochrosiae is monophyletic
# Bactrocera_neohumeralis is non-monophyletic
# Bactrocera_tryoni is non-monophyletic
# Dacus_ciliatus is monophyletic
# Bactrocera_sp105 is monophyletic
# Bactrocera_bhutaniae is non-monophyletic
# Zeugodacus_hochii is monophyletic
# Zeugodacus_scutellatus is monophyletic
# Bactrocera_hantanae is non-monophyletic
# Bactrocera_melas is non-monophyletic
# Zeugodacus_scutellaris is monophyletic
# Zeugodacus_proprescutellatus is monophyletic
# Bactrocera_flavoscutellata is monophyletic
# Dacus_longicornis is monophyletic
# Dacus_vertebratus is monophyletic
# Zeugodacus_diversus is non-monophyletic
# Zeugodacus_cucurbitae is monophyletic
# Bactrocera_propinqua is monophyletic
# Zeugodacus_diaphorus is monophyletic
# Dacus_formosanus is monophyletic
# Bactrocera_alyxiae is monophyletic
# Bactrocera_kraussi is non-monophyletic
# Zeugodacus_hatyaiensis is monophyletic
# Bactrocera_paraarecae is monophyletic
# Zeugodacus_nakhonnayokiae is non-monophyletic
# Zeugodacus_ablepharus is monophyletic
# Bactrocera_perigrapha is monophyletic
# Bactrocera_aquilonis is non-monophyletic
# Bactrocera_endiandrae is monophyletic
# Bactrocera_syzygii is monophyletic
# Bactrocera_frauenfeldi is non-monophyletic
# Bactrocera_caledoniensis is non-monophyletic
# Bactrocera_trilineola is non-monophyletic
# Bactrocera_latifrons is monophyletic
# Bactrocera_correcta is non-monophyletic
# Bactrocera_zonata is non-monophyletic
# Zeugodacus_heinrichi is monophyletic
# Bactrocera_dongnaiae is non-monophyletic
# Bactrocera_clarifemur is monophyletic
# Bactrocera_connecta is monophyletic
# Bactrocera_pendleburyi is monophyletic
# Dacus_aneuvittatus is non-monophyletic
# Dacus_taui is monophyletic
# Bactrocera_nigrifacia is non-monophyletic
# Bactrocera_amarambalensis is monophyletic
# Dacus_discophorus is monophyletic
# Bactrocera_abbreviata is non-monophyletic
# Bactrocera_apicofuscans is monophyletic
# Bactrocera_limbifera is non-monophyletic
# Bactrocera_tenuifascia is non-monophyletic
# Dacus_disjunctus is monophyletic
# Dacus_feijeni is monophyletic
# Bactrocera_pernigra is monophyletic
# Zeugodacus_khaoyaiae is non-monophyletic
# Bactrocera_epicharis is non-monophyletic
# Bactrocera_kolombangarae is monophyletic
# Bactrocera_confluens is monophyletic
# Bactrocera_quasienochra is monophyletic
# Bactrocera_rubigina is monophyletic
# Bactrocera_spnMalaysia03 is monophyletic
# Zeugodacus_vinnulus is monophyletic
# Bactrocera_spMalaysia05 is monophyletic
# Dacus_frontalis is monophyletic
# Zeugodacus_hengsawadae is monophyletic
# Bactrocera_manskii is non-monophyletic
# Bactrocera_quadrata is monophyletic
# Zeugodacus_strigifinis is monophyletic
# Bactrocera_visenda is monophyletic
# Dacus_bivittatus is monophyletic
# Bactrocera_pedestris is monophyletic
# Bactrocera_melanothoracica is monophyletic
# Bactrocera_atrifemur is monophyletic
# Bactrocera_fuscolobata is monophyletic
# Bactrocera_neocognata is monophyletic
# Bactrocera_xanthodes is monophyletic
# Bactrocera_lateritaenia is non-monophyletic
# Bactrocera_dorsalis is non-monophyletic
# Bactrocera_raiensis is non-monophyletic
# Bactrocera_carambolae is non-monophyletic
# Bactrocera_ochroma is monophyletic
# Bactrocera_incognita is non-monophyletic
# Bactrocera_occipitalis is non-monophyletic
# Bactrocera_cacuminata is monophyletic
# Bactrocera_kandiensis is non-monophyletic
# Bactrocera_lata is monophyletic
# Bactrocera_sembaliensis is monophyletic
# Bactrocera_spMalaysia14 is non-monophyletic
# Bactrocera_spBali01 is non-monophyletic
# Bactrocera_adamantea is non-monophyletic
# Zeugodacus_infestus is monophyletic
# Bactrocera_nigrescentis is non-monophyletic
# Bactrocera_linduensis is non-monophyletic
# Bactrocera_melania is monophyletic
# Bactrocera_parafroggatti is monophyletic
# Bactrocera_finitima is monophyletic
# Bactrocera_pallida is monophyletic
# Bactrocera_aethriobasis is monophyletic
# Bactrocera_simulata is monophyletic
# Bactrocera_silvicola is monophyletic
# Dacus_vijaysegarani is non-monophyletic
# Bactrocera_morula is monophyletic
# Bactrocera_decumana is monophyletic
# Dacus_solomonensis is monophyletic
# Bactrocera_kirki is monophyletic
# Dacus_sinensis is monophyletic
# Zeugodacus_synnephes is non-monophyletic
# Zeugodacus_laguniensis is non-monophyletic
# Bactrocera_latilineola is monophyletic
# Dacus_punctatifrons is monophyletic
# Bactrocera_digressa is monophyletic
# Zeugodacus_depressus is monophyletic
# Zeugodacus_arisanicus is monophyletic
# Zeugodacus_triangularis is monophyletic
# Zeugodacus_caudatus is monophyletic
# Dacus_satanas is non-monophyletic
# Bactrocera_hyalina is monophyletic
# Bactrocera_aeroginosa is monophyletic
# Bactrocera_pseudocucurbitae is monophyletic
# Dacus_humeralis is monophyletic
# Bactrocera_ernesti is monophyletic
# Dacus_triquetrus is monophyletic
# Bactrocera_splendida is monophyletic
# Dacus_perpusillus is monophyletic
# Zeugodacus_incisus is non-monophyletic
# Bactrocera_quadrisetosa is non-monophyletic
# Bactrocera_illusioscutellaris is monophyletic
# Bactrocera_nigrofemoralis is non-monophyletic
# Bactrocera_ceylanica is non-monophyletic
# Bactrocera_selenophora is monophyletic
# Zeugodacus_pemalangiae is monophyletic
# Bactrocera_holtmanni is monophyletic
# Zeugodacus_duplicatus is monophyletic
# Dacus_trimacula is monophyletic
# Bactrocera_pseudodistincta is monophyletic
# Bactrocera_pagdeni is monophyletic
# Bactrocera_vargasi is monophyletic
# Bactrocera_tsatsai is monophyletic
# Bactrocera_moluccensis is monophyletic
# Zeugodacus_fuscipennulus is monophyletic
# Bactrocera_mediorufula is monophyletic
# Bactrocera_unimacula is monophyletic
# Zeugodacus_tebeduiae is monophyletic
# Zeugodacus_vultus is monophyletic
# Bactrocera_amplexiseta is monophyletic
# Zeugodacus_angustifinis is monophyletic
# Zeugodacus_madhupuri is monophyletic
# Bactrocera_niogreta is monophyletic
# Bactrocera_commensurata is non-monophyletic
# Dacus_jacobi is non-monophyletic
# Bactrocera_geminosimulata is monophyletic
# Bactrocera_neopropinqua is monophyletic
# Zeugodacus_zahadi is monophyletic
# Dacus_nummularius is monophyletic
# Bactrocera_melanogaster is monophyletic
# Bactrocera_unifasciata is monophyletic
# Zeugodacus_cucumis is monophyletic
# Dacus_siamensis is monophyletic
# Zeugodacus_melanofacies is monophyletic
# Zeugodacus_liquidus is monophyletic
# Dacus_signatifrons is monophyletic
# Dacus_chiwira is monophyletic
# Zeugodacus_lipsanus is monophyletic
# Bactrocera_jarvisi is monophyletic
# Bactrocera_bryoniae is monophyletic
# Bactrocera_bancroftii is monophyletic
# Bactrocera_fulvifacies is monophyletic
# Bactrocera_mucronis is non-monophyletic
# Bactrocera_paraxanthodes is monophyletic
# Bactrocera_curvifera is monophyletic
# Zeugodacus_gracilis is monophyletic
# Bactrocera_redunca is monophyletic
# Bactrocera_obscurata is monophyletic
# Zeugodacus_sinensis is monophyletic
# Zeugodacus_trilineatus is monophyletic
# Dacus_lagunae is monophyletic
# Bactrocera_kinabalu is monophyletic
# Bactrocera_nigrita is monophyletic
# Dacus_fletcheri is monophyletic
# Bactrocera_froggatti is monophyletic
# Bactrocera_allodistincta is monophyletic
# Bactrocera_aterrima is monophyletic
# Zeugodacus_hamaceki is monophyletic
# Zeugodacus_spnMalaysia02 is monophyletic
# Zeugodacus_apicalis is monophyletic
# Bactrocera_megaspilus is monophyletic
# Bactrocera_dorsaloides is monophyletic
# Dacus_ancoralis is monophyletic
# Dacus_pullus is monophyletic
# Zeugodacus_abdoangustus is non-monophyletic
# Zeugodacus_longivittatus is monophyletic
# Bactrocera_laithieuiae is monophyletic
# Bactrocera_tsuneonis is monophyletic
# Bactrocera_anomala is monophyletic
# Dacus_eclipsis is monophyletic
# Bactrocera_spMalaysia11 is non-monophyletic
# Bactrocera_spnSol08 is monophyletic
# Bactrocera_continua is monophyletic
# Zeugodacus_univittatus is monophyletic
# Bactrocera_minuta is non-monophyletic
# Zeugodacus_choristus is non-monophyletic
# Bactrocera_ebenea is monophyletic
# Zeugodacus_elegantulus is monophyletic
# Bactrocera_calophylli is monophyletic
# Bactrocera_curvipennis is monophyletic
# Bactrocera_oleae is monophyletic
# Zeugodacus_isolatus is monophyletic
# Dacus_pullescens is monophyletic
# Dacus_aequalis is monophyletic
# Dacus_absonifacies is monophyletic
# Bactrocera_spMyanmar01 is monophyletic
# Bactrocera_abscondita is monophyletic
# Zeugodacus_tappanus is monophyletic
# Dacus_axanus is monophyletic
# Zeugodacus_yoshimotoi is monophyletic
# Ceratitis_capitata is monophyletic
# Dacus_pedunculatus is monophyletic
# Bactrocera_paranigrita is monophyletic
# Bactrocera_neoxanthodes is monophyletic
# Bactrocera_laithieuae is monophyletic
# Bactrocera_involuta is monophyletic
# Bactrocera_minax is monophyletic
# Bactrocera_perkinsi is monophyletic
# Dacus_transversus is monophyletic
# Zeugodacus_uncinatus is monophyletic
# Bactrocera_enochra is monophyletic
# Bactrocera_hollingsworthi is monophyletic
# Zeugodacus_speciosus is monophyletic
# Dacus_spnMalaysia01 is monophyletic
# Dacus_jubatus is monophyletic
# Dacus_siliqualactis is monophyletic
# Bactrocera_bivittata is monophyletic
# Bactrocera_passifloraespnear is non-monophyletic
# Zeugodacus_fallacis is monophyletic
# Zeugodacus_persignatus is monophyletic
# Bactrocera_musae is non-monophyletic
# Bactrocera_biarcuata is monophyletic
# Zeugodacus_signatus is monophyletic
# Bactrocera_spMalayisa14 is monophyletic

# %%
inputtreeclean = os.path.splitext(inputtree)[0]
outputfile = str(str(inputtreeclean) + "_monophyly.csv")

totaldf = pd.DataFrame(speciesstatus)
totaldf.to_csv(outputfile, index=False)
print("Output written to " + str(outputfile))
# Out:
# Output written to 5605taxa_COImini.fasta.treefilerooted_monophyly.csv

# %%
tree.is_monophyletic(tree.find_clades({"name": "Dacus_pedunculatus.*"}))
# Out:
# Clade(branch_length=0.2622883114)

# %%
try:
    tree.root_with_outgroup({"name": 'Bactrocera_dorsalis'})
except Exception as e: print(taxon + e)
# Out:
# target 'name' is not in this tree
